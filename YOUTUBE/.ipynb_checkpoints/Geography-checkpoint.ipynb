# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the data
data = {"Month" : ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"],	    
        "Temp(degrees)" : [-2.9, 0.3, 3.7, 8.7,13.4, 17.1, 20.1, 19.2, 14.7, 8.7, 3.1, -0.4],
       "Prec(nm)" : [31.5, 20.8, 16.5, 23.1, 27.7, 35.6, 24.6, 22.4, 18, 19.8, 25.7, 30.5]}
climate_data = pd.DataFrame(data)
climate_data.head(2)
# Out:
#   Month  Temp(degrees)  Prec(nm)
# 0   Jan           -2.9      31.5
# 1   Feb            0.3      20.8

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 4
#       2 plt.figure(figsize=(10,5))
#       3 plt.plot(climate_data['Month'], climate_data["Temp(degrees)"], label='Temperature')
# ----> 4 climate_data["Prec(nm)"].plot(climate_data['Month'], climate_data["Prec(nm)"], label='Precipitation')
#       5 plt.xlabel('Month')
#       6 plt.ylabel('Temperature (°C) & Precipitation(mm)')
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:949, in PlotAccessor.__call__(self, *args, **kwargs)
#     946 def __call__(self, *args, **kwargs):
#     947     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
# --> 949     x, y, kind, kwargs = self._get_call_args(
#     950         plot_backend.__name__, self._parent, args, kwargs
#     951     )
#     953     kind = self._kind_aliases.get(kind, kind)
#     955     # when using another backend, get out of the way
#
# File ~\anaconda3\Lib\site-packages\pandas\plotting\_core.py:933, in PlotAccessor._get_call_args(backend_name, data, args, kwargs)
#     923     keyword_args = ", ".join(
#     924         [f"{name}={repr(value)}" for (name, _), value in zip(arg_def, args)]
#     925     )
#     926     msg = (
#     927         "`Series.plot()` should not be called with positional "
#     928         "arguments, only keyword arguments. The order of "
#    (...)
#     931         f"`Series.plot({positional_args})`."
#     932     )
# --> 933     raise TypeError(msg)
#     935 pos_args = {name: value for (name, _), value in zip(arg_def, args)}
#     936 if backend_name == "pandas.plotting._matplotlib":
#
# TypeError: `Series.plot()` should not be called with positional arguments, only keyword arguments. The order of positional arguments will change in the future. Use `Series.plot(kind=0     Jan
# 1     Feb
# 2     Mar
# 3     Apr
# 4     May
# 5     Jun
# 6     Jul
# 7     Aug
# 8     Sep
# 9     Oct
# 10    Nov
# 11    Dec
# Name: Month, dtype: object, ax=0     31.5
# 1     20.8
# 2     16.5
# 3     23.1
# 4     27.7
# 5     35.6
# 6     24.6
# 7     22.4
# 8     18.0
# 9     19.8
# 10    25.7
# 11    30.5
# Name: Prec(nm), dtype: float64)` instead of `Series.plot(0     Jan
# 1     Feb
# 2     Mar
# 3     Apr
# 4     May
# 5     Jun
# 6     Jul
# 7     Aug
# 8     Sep
# 9     Oct
# 10    Nov
# 11    Dec
# Name: Month, dtype: object, 0     31.5
# 1     20.8
# 2     16.5
# 3     23.1
# 4     27.7
# 5     35.6
# 6     24.6
# 7     22.4
# 8     18.0
# 9     19.8
# 10    25.7
# 11    30.5
# Name: Prec(nm), dtype: float64)`.
